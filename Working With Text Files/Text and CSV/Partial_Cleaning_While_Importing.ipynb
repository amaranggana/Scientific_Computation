# %%
import numpy as np

# %% [markdown]
# ***Partial Cleaning While Importing - Exercise #1***
# Using the arguments of the np.genfromtxt() function, perform the following data cleaning steps:
# 1. Set the data type to string.
# 2. Skip the first row of the dataset.
# 3. Skip the last 15 rows of the dataset.
# 4. Load only the 2nd, 3rd, and 5th columns.

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price-100.csv", 
                              delimiter = ',', 
                              dtype = str,
                              skip_header= 1,
                              skip_footer=15,
                              usecols=(1,3,4))

print(lending_co_TP)
# Out:
# [['id_1' 'Male' 'Location 2']
#  ['id_2' 'Male' 'Location 3']
#  ['id_3' 'Female' 'Location 5']
#  ['id_4' 'Male' 'Location 6']
#  ['id_5' 'Female' 'Location 7']
#  ['id_6' 'Female' 'Location 10']
#  ['id_7' 'Male' 'Location 11']
#  ['id_8' 'Male' 'Location 12']
#  ['id_9' 'Female' 'Location 3']
#  ['id_10' 'Female' 'Location 13']
#  ['id_11' 'Female' 'Location 15']
#  ['id_12' 'Female' 'Location 16']
#  ['id_13' 'Male' 'Location 17']
#  ['id_14' 'Male' 'Location 19']
#  ['id_15' 'Female' 'Location 23']
#  ['id_16' 'Male' 'Location 27']
#  ['id_17' 'Male' 'Location 25']
#  ['id_18' 'Female' 'Location 26']
#  ['id_19' 'Male' 'Location 29']
#  ['id_20' 'Male' 'Location 30']
#  ['id_21' 'Male' 'Location 31']
#  ['id_22' 'Male' 'Location 17']
#  ['id_23' 'Male' 'Location 33']
#  ['id_24' 'NotSpecified' 'Location 34']
#  ['id_25' 'Female' 'Location 35']
#  ['id_26' 'Male' 'Location 37']
#  ['id_27' 'Female' 'Location 38']
#  ['id_28' 'Female' 'Location 39']
# ...

# %% [markdown]
# *** Partial Cleaning While Importing - Exercise #2 ***
# Now that you understand how the np.genfromtext() function works, set its parameters with the following arguments in the given code (lines 4 to 15 inclusive):
# 1. Use a comma as the delimiter for the dataset.
# 2. Set the data type of the values to string.
# 3. Skip the first row of the dataset.
# 4. Skip the last fifteen rows of the dataset.
# 5. Load only the second, third, and fifth columns from "Lending-Company-Total-Price-100.csv".
# 6. Use # to indicate the start of a comment.
# 7. Indicate that no data conversions are required (i.e., leave converters=None).
# 8. Ensure that only empty fields are treated as missing data.
# 9. Ensure that no field names are excluded from the retrieved dataset.
# 10. Remove the following characters from field names: ()*+,-./:;<=>?@[\\]^{|}~
# 11. Replace whitespaces in field names with underscores.
# 12. Automatically strip leading and trailing whitespaces from field names.

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price-100.csv",
                              delimiter= ',', 
                              dtype=str,
                              skip_header=1,
                              skip_footer=15,
                              usecols=(1,2,4),
                              comments="#",
                              converters=None,
                              missing_values=None,
                              filling_values="0",
                              excludelist=None,
                              deletechars="()*+,-./:;<=>?@[\\]^{|}~",
                              replace_space="_",
                              autostrip=True)
                         
print(lending_co_TP)
# Out:
# [['id_1' 'Product B' 'Location 2']
#  ['id_2' 'Product B' 'Location 3']
#  ['id_3' 'Product C' 'Location 5']
#  ['id_4' 'Product B' 'Location 6']
#  ['id_5' 'Product D' 'Location 7']
#  ['id_6' 'Product B' 'Location 10']
#  ['id_7' 'Product A' 'Location 11']
#  ['id_8' 'Product B' 'Location 12']
#  ['id_9' 'Product A' 'Location 3']
#  ['id_10' 'Product A' 'Location 13']
#  ['id_11' 'Product B' 'Location 15']
#  ['id_12' 'Product D' 'Location 16']
#  ['id_13' 'Product B' 'Location 17']
#  ['id_14' 'Product A' 'Location 19']
#  ['id_15' 'Product A' 'Location 23']
#  ['id_16' 'Product B' 'Location 27']
#  ['id_17' 'Product A' 'Location 25']
#  ['id_18' 'Product B' 'Location 26']
#  ['id_19' 'Product B' 'Location 29']
#  ['id_20' 'Product E' 'Location 30']
#  ['id_21' 'Product B' 'Location 31']
#  ['id_22' 'Product A' 'Location 17']
#  ['id_23' 'Product A' 'Location 33']
#  ['id_24' 'Product C' 'Location 34']
#  ['id_25' 'Product D' 'Location 35']
#  ['id_26' 'Product A' 'Location 37']
# ...

# %% [markdown]
# ***Partial Cleaning While Importing - Exercise #3***
# Display the contents of lending_co_TP to the console.
# Load only the first and last columns of the "Lending-Company-Total-Price-100.csv" file into a two-dimensional array named lending_co_TP, using a comma as the delimiter, a string data type, and skipping the first row.

# %%
data = np.genfromtxt("Lending-Company-Total-Price-100.csv", usecols=(0,6),delimiter=',',dtype=str,skip_header=1)
lending_co_TP = np.array(data)
print(lending_co_TP)
# Out:
# [['"1' '16600"']
#  ['"2' '16600"']
#  ['"3' '15600"']
#  ['"4' '16600"']
#  ['"5' '20250"']
#  ['"6' '"']
#  ['"7' '20250"']
#  ['"8' '16600"']
#  ['"9' '22250"']
#  ['"10' '20250"']
#  ['"11' '16600"']
#  ['"12' '20250"']
#  ['"13' '16600"']
#  ['"14' '20750"']
#  ['"15' '22250"']
#  ['"16' '16600"']
#  ['"17' '22250"']
#  ['"18' '16600"']
#  ['"19' '16600"']
#  ['"20' '54625"']
#  ['"21' '16600"']
#  ['"22' '22250"']
#  ['"23' '19250"']
#  ['"24' '15600"']
#  ['"25' '20250"']
#  ['"26' '22250"']
#  ['"27' '19250"']
#  ['"28' '69225"']
#  ['"29' '20250"']
#  ['"30' '16600"']
#  ['"31' '16600"']
#  ['"32' '16600"']
#  ['"33' '19250"']
#  ['"34' '16600"']
#  ['"35' '19250"']
#  ['"36' '16600"']
#  ['"37' '16600"']
#  ['"38' '16600"']
#  ['"39' '15600"']
#  ['"40' '16600"']
#  ['"41' '16600"']
#  ['"42' '16600"']
#  ['"43' '19250"']
#  ['"44' '15600"']
#  ['"45' '19250"']
#  ['"46' '16600"']
#  ['"47' '16600"']
#  ['"48' '16600"']
#  ['"49' '20250"']
#  ['"50' '22250"']
# ...

# %% [markdown]
# ***Partial Cleaning While Importing - Exercise #4***
# Similar to the previous exercise, load only the first and last columns of the "Lending-Company-Total-Price-100.csv" file into a two-dimensional array named lending_co_TP, using a comma as the delimiter and skipping the first row. This time, however, use 32-bit NumPy float data types.
#
# Display the contents of lending_co_TP to the console.

# %%
lending_co_TP = np.array(np.genfromtxt("Lending-Company-Total-Price-100.csv", usecols=(0,6),delimiter=',',skip_header=1,dtype=(float)))
print(lending_co_TP)
# Out:
# [[nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
#  [nan nan]
# ...
